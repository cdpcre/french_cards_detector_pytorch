# %% [markdown]
# # French Cards Detector - EDA and Training
#
# This notebook covers the Exploratory Data Analysis (EDA) and model training for the French Cards Detector project.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import os
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO
import glob

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
#
# We will inspect the dataset to understand the distribution of classes and visualize some samples.

# %%
# TODO: Point this to your dataset path
dataset_path = 'datasets/playing-cards'

# Example: Count images
# images = glob.glob(os.path.join(dataset_path, 'train/images/*.jpg'))
# print(f"Number of training images: {len(images)}")

# %% [markdown]
# ## 3. Model Training
#
# We use YOLOv8n for training.

# %%
# model = YOLO('yolov8n.pt')
# results = model.train(data='data.yaml', epochs=10, imgsz=640)
