# %% [markdown]
# # French Cards Detector - EDA and Training
#
# This notebook covers the Exploratory Data Analysis (EDA) and model training for the French Cards Detector project.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import os
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO
import glob

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
#
# We will inspect the dataset to understand the distribution of classes and visualize some samples.

# %%
# Dataset path configured in data.yaml
dataset_path = '/Users/crescenzodepalma/Projects/cdpcre/french_cards_detector_pytorch/datasets/unified'

# Example: Count images
train_images = glob.glob(os.path.join(dataset_path, 'images/train/*.jpg'))
print(f"Number of training images: {len(train_images)}")
# Out:
# Number of training images: 64138
